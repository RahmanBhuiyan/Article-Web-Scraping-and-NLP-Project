# %% [markdown]
# # <div style="text-align: center; background-color: #000000; font-family: Alliance No.1  MS; color: #fafafa; padding: 14px; line-height: 1;border-radius:20px; font-size:40px">Article Web Scraping & NLP</div>

# %% [markdown]
# <div style="text-align:center"><img src="https://challengingcoder.com/wp-content/uploads/2022/02/Web-Scraping.png">

# %% [markdown]
# <a id="0.2"></a>
# <h3 style="text-align: center;background-color: #000000; font-family:Alliance No.1 MS; color: #fafafa; padding: 14px; line-height: 1; border-radius:10px; font-size:25px"> Objectives</h3>

# %% [markdown]
# <div style="border-radius:10px;
#             border :#0A0104 solid;
#             padding: 15px;
#             background-color:#00000   ;
#            font-size:110%;
#             text-align: left">
#
# <h4>Objective of this project is to scrape article text from all of the given urls and then perform text analysis on them to find the value of different variables.</h4>

# %% [markdown]
# <div style="border-radius:10px;
#             border :#0A0104 solid;
#             padding: 15px;
#             background-color:#00000   ;
#            font-size:120%;
#             text-align: left">
#
# * Data Extraction(Web Scraping)
# * Exploratory Data Analysis
# * Find the values of these Variables:
#     - POSITIVE SCORE
#     - NEGATIVE SCORE
#     - POLARITY SCORE
#     - SUBJECTIVITY SCORE
#     - AVG SENTENCE LENGTH
#     - PERCENTAGE OF COMPLEX WORDS
#     - FOG INDEX
#     - AVG NUMBER OF WORDS PER SENTENCE
#     - COMPLEX WORD COUNT
#     - WORD COUNT
#     - SYLLABLE PER WORD
#     - PERSONAL PRONOUNS
#     - AVG WORD LENGTH

# %% [markdown]
# <a id="0.2"></a>
# <h3 style="text-align: center;background-color: #000000; font-family:Alliance No.1 MS; color: #fafafa; padding: 14px; line-height: 1; border-radius:10px; font-size:25px"> Web Scraping</h3>

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup,NavigableString
data = pd.read_csv('../input/nlp-text-analysis/Data.csv')
data.head()
data.tail()
# Out:
#      URL_ID                                                URL
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...

# %%
#read the name of the file from the url - done
#check if the file exists in the directory - 
#if yes then skip , else request the date from the url and save it to the dataframe

# %%
#to create a folder for all the files
import os
os.makedirs('data')

# %%
#to read the title of the file from the urls
l=[]
for url in data['URL']:
    title=url.split('/')[3]
    file_name=title+'.html'
    file_path='./data/' + file_name 
#to scrape the data from the url and save it to the file if the file doesnt exist in the directory
    if not os.path.exists(file_path):
        #print('file doesnt exists')
        with open(file_path,'w') as f:
            r = requests.get(url, headers={"User-Agent": "XY"})
            htmlcontent=r.content.decode()
            f.write(htmlcontent)
#to open each file and retrieve the beautifulsoup from the htmlcontent and put it in a dataframe
    with open (file_path,'r')as f:  
        htmlcontent=f.read()
    soup = BeautifulSoup(htmlcontent, 'html.parser')
    title = soup.title
    article_content = soup.find('div', attrs={'class': 'td-post-content'})
    if article_content is None:
        #print('break')
        continue
    article_text=''
    for element in article_content:
        if not isinstance(element, NavigableString):
            text = element.text
            article_text+=text
    l.append(article_text)

df=pd.DataFrame(l,columns=['Text'])
df.head()
# Out:
#                                                 Text
# 0  Introduction“If anything kills over 10 million...
# 1  Human minds, a fascination in itself carrying ...
# 2  IntroductionAI is rapidly evolving in the empl...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...

# %% [markdown]
# <a id="0.2"></a>
# <h3 style="text-align: center;background-color: #000000; font-family:Alliance No.1 MS; color: #fafafa; padding: 14px; line-height: 1; border-radius:10px; font-size:25px"> Exploratory Data Analysis</h3>

# %%
import pandas as pd
outputfile=pd.read_csv('../input/output-data-structure/Output Data Structure.xlsx - Sheet1.csv')
outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0       1  https://insights.blackcoffer.com/how-is-login-...             NaN
# 1       2  https://insights.blackcoffer.com/how-does-ai-h...             NaN
# 2       3  https://insights.blackcoffer.com/ai-and-its-im...             NaN
# 3       4  https://insights.blackcoffer.com/how-do-deep-l...             NaN
# 4       5  https://insights.blackcoffer.com/how-artificia...             NaN
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0             NaN             NaN                 NaN                  NaN
# 1             NaN             NaN                 NaN                  NaN
# 2             NaN             NaN                 NaN                  NaN
# 3             NaN             NaN                 NaN                  NaN
# 4             NaN             NaN                 NaN                  NaN
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                          NaN        NaN                               NaN
# 1                          NaN        NaN                               NaN
# 2                          NaN        NaN                               NaN
# 3                          NaN        NaN                               NaN
# 4                          NaN        NaN                               NaN
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0                 NaN         NaN                NaN                NaN
# 1                 NaN         NaN                NaN                NaN
# 2                 NaN         NaN                NaN                NaN
# 3                 NaN         NaN                NaN                NaN
# 4                 NaN         NaN                NaN                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# **CLEANING USING STOP WORDS LIST**

# %%
#from nltk.tokenize import word_tokenize


from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
l=[]
for i in range(111):
    
    example_sent = df['Text'][i]
  
    stop_words = set(stopwords.words('english'))
  
    word_tokens = word_tokenize(example_sent)
  
    filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
  
    filtered_sentence = []
    
    for w in word_tokens:
        if w not in stop_words:
            filtered_sentence.append(w)
    
    new_sentence=' '.join(filtered_sentence)
    l.append(new_sentence)
df=pd.DataFrame(l,columns=['Text'])
  
#print(word_tokens)
df.head()
# Out:
#                                                 Text
# 0  Introduction “ If anything kills 10 million pe...
# 1  Human minds , fascination carrying potential t...
# 2  IntroductionAI rapidly evolving employment sec...
# 3  “ Anything could give rise smarter-than-human ...
# 4  “ Machine intelligence last invention humanity...

# %% [markdown]
# **POSITIVE SCORE**

# %%
#to read the Positive-scores.txt file as a dataframe and changing the first entry


import pandas as pd
pw=pd.read_csv('../input/positivewordstxt/positive-words.txt')

new_row=pd.DataFrame({'a+':'a+'},index=[0])
pw=pd.concat([new_row,pw.loc[:].reset_index(drop=True)])
pw.columns=['0']
pw.reset_index(drop=True,inplace=True)
pw.head(100)
# Out:
#               0
# 0            a+
# 1        abound
# 2       abounds
# 3     abundance
# 4      abundant
# ..          ...
# 95   amiability
# 96     amiabily
# 97      amiable
# 98  amicability
# 99     amicable
#
# [100 rows x 1 columns]

# %%
# code to find and enter the the positive score of each url file in the output file

for i in range(111):
    ps=0
    #print(type(df['Text'][i]))
    for word in pw['0']:
        
        if word in df['Text'][i].lower():
            ps+=1
    outputfile.at[i,'POSITIVE SCORE']=ps

outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0       1  https://insights.blackcoffer.com/how-is-login-...            81.0
# 1       2  https://insights.blackcoffer.com/how-does-ai-h...            61.0
# 2       3  https://insights.blackcoffer.com/ai-and-its-im...            85.0
# 3       4  https://insights.blackcoffer.com/how-do-deep-l...            73.0
# 4       5  https://insights.blackcoffer.com/how-artificia...            74.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            82.0       -0.006135            0.120920            20.175438
# 1            74.0       -0.096296            0.135815            11.056338
# 2            89.0       -0.022989            0.143564            15.208955
# 3            69.0        0.028169            0.127126            11.750000
# 4            81.0       -0.045161            0.126016            13.026316
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                     0.768696   8.377654                         20.175439
# 1                     0.668790   4.690051                         11.056338
# 2                     0.787046   6.398400                         15.208955
# 3                     0.667021   4.966808                         11.750000
# 4                     0.727273   5.501435                         13.026316
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0               607.0      1150.0             3123.0                1.0
# 1               607.0       785.0             1872.0                1.0
# 2               607.0      1019.0             2828.0                1.0
# 3               607.0       940.0             2160.0                1.0
# 4               607.0       990.0             2492.0                1.0
#
#    AVG WORD LENGTH
# 0         7.267826
# 1         6.412739
# 2         7.245339
# 3         6.346809
# 4         6.798990

# %% [markdown]
# **NEGATIVE SCORE**

# %%
#code to read and change the negative_words file data to a dataframe
import pandas as pd
with open('../input/negativewordstxt/negative-words.txt', 'rb') as nw:
    words = [str(w)[2:-3]for w in nw]
    
    nw=pd.DataFrame(words,columns=['Negative_words'])
    
    print(nw)
# Out:
#      Negative_words
# 0           2-faced
# 1           2-faces
# 2          abnormal
# 3           abolish
# 4        abominable
# ...             ...
# 4778           zaps
# 4779         zealot
# 4780        zealous
# 4781      zealously
# 4782         zombie
#
# [4783 rows x 1 columns]

# %%
#code to find the negative score of each url file in the output file
for i in range(111):
    ns=0
    #print(type(df['Text'][i]))
    for word in nw['Negative_words']:
        
        if word in df['Text'][i].lower():
            ns+=1
    outputfile.at[i,'NEGATIVE SCORE']=ns

outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0       1  https://insights.blackcoffer.com/how-is-login-...            81.0
# 1       2  https://insights.blackcoffer.com/how-does-ai-h...            61.0
# 2       3  https://insights.blackcoffer.com/ai-and-its-im...            85.0
# 3       4  https://insights.blackcoffer.com/how-do-deep-l...            73.0
# 4       5  https://insights.blackcoffer.com/how-artificia...            74.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            82.0             NaN                 NaN                  NaN
# 1            74.0             NaN                 NaN                  NaN
# 2            89.0             NaN                 NaN                  NaN
# 3            69.0             NaN                 NaN                  NaN
# 4            81.0             NaN                 NaN                  NaN
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                          NaN        NaN                               NaN
# 1                          NaN        NaN                               NaN
# 2                          NaN        NaN                               NaN
# 3                          NaN        NaN                               NaN
# 4                          NaN        NaN                               NaN
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0                 NaN         NaN                NaN                NaN
# 1                 NaN         NaN                NaN                NaN
# 2                 NaN         NaN                NaN                NaN
# 3                 NaN         NaN                NaN                NaN
# 4                 NaN         NaN                NaN                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# **POLARITY SCORE**

# %%
#polarity_score=(pos-nes)/((pos+nes)+0.000001)
for i in range(170):
    pols=0
    #print(type(df['Text'][i]))
    pos=outputfile['POSITIVE SCORE'][i]
    nes=outputfile['NEGATIVE SCORE'][i]
    pols=(pos-nes)/((pos+nes)+0.000001)
        
        
    outputfile.at[i,'POLARITY SCORE']=pols

outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0       1  https://insights.blackcoffer.com/how-is-login-...            81.0
# 1       2  https://insights.blackcoffer.com/how-does-ai-h...            61.0
# 2       3  https://insights.blackcoffer.com/ai-and-its-im...            85.0
# 3       4  https://insights.blackcoffer.com/how-do-deep-l...            73.0
# 4       5  https://insights.blackcoffer.com/how-artificia...            74.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            82.0       -0.006135                 NaN                  NaN
# 1            74.0       -0.096296                 NaN                  NaN
# 2            89.0       -0.022989                 NaN                  NaN
# 3            69.0        0.028169                 NaN                  NaN
# 4            81.0       -0.045161                 NaN                  NaN
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                          NaN        NaN                               NaN
# 1                          NaN        NaN                               NaN
# 2                          NaN        NaN                               NaN
# 3                          NaN        NaN                               NaN
# 4                          NaN        NaN                               NaN
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0                 NaN         NaN                NaN                NaN
# 1                 NaN         NaN                NaN                NaN
# 2                 NaN         NaN                NaN                NaN
# 3                 NaN         NaN                NaN                NaN
# 4                 NaN         NaN                NaN                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# **SUBJECTIVITY SCORE**

# %%
#SUBJECTIVITY SCORE=(pos+nes)/((total no.of words)+0.000001)
for i in range(111):
    
    #print(type(df['Text'][i]))
    text=df['Text'][i].split()
    pos=outputfile['POSITIVE SCORE'][i]
    nes=outputfile['NEGATIVE SCORE'][i]
    nofwords=len(text)
    subs=(pos+nes)/(nofwords+0.000001)
        
        
    outputfile.at[i,'SUBJECTIVITY SCORE']=subs

outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0       1  https://insights.blackcoffer.com/how-is-login-...            81.0
# 1       2  https://insights.blackcoffer.com/how-does-ai-h...            61.0
# 2       3  https://insights.blackcoffer.com/ai-and-its-im...            85.0
# 3       4  https://insights.blackcoffer.com/how-do-deep-l...            73.0
# 4       5  https://insights.blackcoffer.com/how-artificia...            74.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            82.0       -0.006135            0.120920                  NaN
# 1            74.0       -0.096296            0.135815                  NaN
# 2            89.0       -0.022989            0.143564                  NaN
# 3            69.0        0.028169            0.127126                  NaN
# 4            81.0       -0.045161            0.126016                  NaN
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                          NaN        NaN                               NaN
# 1                          NaN        NaN                               NaN
# 2                          NaN        NaN                               NaN
# 3                          NaN        NaN                               NaN
# 4                          NaN        NaN                               NaN
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0                 NaN         NaN                NaN                NaN
# 1                 NaN         NaN                NaN                NaN
# 2                 NaN         NaN                NaN                NaN
# 3                 NaN         NaN                NaN                NaN
# 4                 NaN         NaN                NaN                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# **AVG SENTENCE LENGTH**

# %%
#avg sentence length= the number of words / the number of sentences
from nltk.tokenize import sent_tokenize,word_tokenize
for i in range(111):
    
    #print(type(df['Text'][i]))
    text=df['Text'][i]
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    nofwords=len(word_list)
    nofsents=len(sent_tokenize(text))
    avgsl=(nofwords)/(nofsents+0.000001)
        
        
    outputfile.at[i,'AVG SENTENCE LENGTH']=avgsl

outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0       1  https://insights.blackcoffer.com/how-is-login-...            81.0
# 1       2  https://insights.blackcoffer.com/how-does-ai-h...            61.0
# 2       3  https://insights.blackcoffer.com/ai-and-its-im...            85.0
# 3       4  https://insights.blackcoffer.com/how-do-deep-l...            73.0
# 4       5  https://insights.blackcoffer.com/how-artificia...            74.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            82.0       -0.006135            0.120920            20.175438
# 1            74.0       -0.096296            0.135815            11.056338
# 2            89.0       -0.022989            0.143564            15.208955
# 3            69.0        0.028169            0.127126            11.750000
# 4            81.0       -0.045161            0.126016            13.026316
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                          NaN        NaN                               NaN
# 1                          NaN        NaN                               NaN
# 2                          NaN        NaN                               NaN
# 3                          NaN        NaN                               NaN
# 4                          NaN        NaN                               NaN
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0                 NaN         NaN                NaN                NaN
# 1                 NaN         NaN                NaN                NaN
# 2                 NaN         NaN                NaN                NaN
# 3                 NaN         NaN                NaN                NaN
# 4                 NaN         NaN                NaN                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# **COMPLEX WORD PERCENTAGE**

# %%
#POCW=nofcw/nofwords
pofcw=0
for i in range(111):
    text=df['Text'][i]
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    nofwords=len(word_list)
    vowels='aeiou'
    nofcw=0
    for w in word_list:
        vc=0 #vowelcount
        for v in vowels:
            if v in w:
                vc+=1
        if vc>1:
            nofcw+=1
                
    pofcw=nofcw/nofwords
    
    outputfile.at[i,'PERCENTAGE OF COMPLEX WORDS']=pofcw
    
outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0       1  https://insights.blackcoffer.com/how-is-login-...            81.0
# 1       2  https://insights.blackcoffer.com/how-does-ai-h...            61.0
# 2       3  https://insights.blackcoffer.com/ai-and-its-im...            85.0
# 3       4  https://insights.blackcoffer.com/how-do-deep-l...            73.0
# 4       5  https://insights.blackcoffer.com/how-artificia...            74.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            82.0       -0.006135            0.120920            20.175438
# 1            74.0       -0.096296            0.135815            11.056338
# 2            89.0       -0.022989            0.143564            15.208955
# 3            69.0        0.028169            0.127126            11.750000
# 4            81.0       -0.045161            0.126016            13.026316
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                     0.768696        NaN                               NaN
# 1                     0.668790        NaN                               NaN
# 2                     0.787046        NaN                               NaN
# 3                     0.667021        NaN                               NaN
# 4                     0.727273        NaN                               NaN
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0                 NaN         NaN                NaN                NaN
# 1                 NaN         NaN                NaN                NaN
# 2                 NaN         NaN                NaN                NaN
# 3                 NaN         NaN                NaN                NaN
# 4                 NaN         NaN                NaN                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
#import nltk
#nltk.download('punkt')

# %% [markdown]
# **FOG INDEX**

# %%
#fogi=0.4*(avgsl+pofcw)
fogi=0
for i in range(111):
    text=df['Text'][i]
    
    #to find avgsl
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    nofwords=len(word_list)
    nofsents=len(sent_tokenize(text))
    avgsl=(nofwords)/(nofsents+0.000001)
    
    #to find pofcw
    vowels='aeiou'
    nofcw=0
    for w in word_list:
        vc=0 #vowelcount
        for v in vowels:
            if v in w:
                vc+=1
        if vc>1:
            nofcw+=1
    pofcw=nofcw/nofwords
    
    fogi=0.4*(avgsl+pofcw)
    
    outputfile.at[i,'FOG INDEX']=fogi

outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0       1  https://insights.blackcoffer.com/how-is-login-...            81.0
# 1       2  https://insights.blackcoffer.com/how-does-ai-h...            61.0
# 2       3  https://insights.blackcoffer.com/ai-and-its-im...            85.0
# 3       4  https://insights.blackcoffer.com/how-do-deep-l...            73.0
# 4       5  https://insights.blackcoffer.com/how-artificia...            74.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            82.0       -0.006135            0.120920            20.175438
# 1            74.0       -0.096296            0.135815            11.056338
# 2            89.0       -0.022989            0.143564            15.208955
# 3            69.0        0.028169            0.127126            11.750000
# 4            81.0       -0.045161            0.126016            13.026316
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                     0.768696   8.377654                               NaN
# 1                     0.668790   4.690051                               NaN
# 2                     0.787046   6.398400                               NaN
# 3                     0.667021   4.966808                               NaN
# 4                     0.727273   5.501435                               NaN
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0                 NaN         NaN                NaN                NaN
# 1                 NaN         NaN                NaN                NaN
# 2                 NaN         NaN                NaN                NaN
# 3                 NaN         NaN                NaN                NaN
# 4                 NaN         NaN                NaN                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# **AVG NUMBER OF WORDS PER SENTENCE**

# %%
#anofwps=nofwords/nofsents
for i in range(111):
    text=df['Text'][i]
    
    #to find avgsl
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    nofwords=len(word_list)
    nofsents=len(sent_tokenize(text))
    anofwps=nofwords/nofsents
    
    outputfile.at[i,'AVG NUMBER OF WORDS PER SENTENCE']=anofwps

outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0       1  https://insights.blackcoffer.com/how-is-login-...            81.0
# 1       2  https://insights.blackcoffer.com/how-does-ai-h...            61.0
# 2       3  https://insights.blackcoffer.com/ai-and-its-im...            85.0
# 3       4  https://insights.blackcoffer.com/how-do-deep-l...            73.0
# 4       5  https://insights.blackcoffer.com/how-artificia...            74.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            82.0       -0.006135            0.120920            20.175438
# 1            74.0       -0.096296            0.135815            11.056338
# 2            89.0       -0.022989            0.143564            15.208955
# 3            69.0        0.028169            0.127126            11.750000
# 4            81.0       -0.045161            0.126016            13.026316
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                     0.768696   8.377654                         20.175439
# 1                     0.668790   4.690051                         11.056338
# 2                     0.787046   6.398400                         15.208955
# 3                     0.667021   4.966808                         11.750000
# 4                     0.727273   5.501435                         13.026316
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0                 NaN         NaN                NaN                NaN
# 1                 NaN         NaN                NaN                NaN
# 2                 NaN         NaN                NaN                NaN
# 3                 NaN         NaN                NaN                NaN
# 4                 NaN         NaN                NaN                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# **COMPLEX WORD COUNT**

# %%
for i in range(111):
    text=df['Text'][i]
    
    vowels='aeiou'
    nofcw=0
    
    for w in word_list:
        for v in vowels:
            if v in w:
                nofcw+=1
                break
    
    
    outputfile.at[i,'COMPLEX WORD COUNT']=nofcw
    
outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0       1  https://insights.blackcoffer.com/how-is-login-...            81.0
# 1       2  https://insights.blackcoffer.com/how-does-ai-h...            61.0
# 2       3  https://insights.blackcoffer.com/ai-and-its-im...            85.0
# 3       4  https://insights.blackcoffer.com/how-do-deep-l...            73.0
# 4       5  https://insights.blackcoffer.com/how-artificia...            74.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            82.0       -0.006135            0.120920            20.175438
# 1            74.0       -0.096296            0.135815            11.056338
# 2            89.0       -0.022989            0.143564            15.208955
# 3            69.0        0.028169            0.127126            11.750000
# 4            81.0       -0.045161            0.126016            13.026316
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                     0.768696   8.377654                         20.175439
# 1                     0.668790   4.690051                         11.056338
# 2                     0.787046   6.398400                         15.208955
# 3                     0.667021   4.966808                         11.750000
# 4                     0.727273   5.501435                         13.026316
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0               607.0         NaN                NaN                NaN
# 1               607.0         NaN                NaN                NaN
# 2               607.0         NaN                NaN                NaN
# 3               607.0         NaN                NaN                NaN
# 4               607.0         NaN                NaN                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# **WORD COUNT**

# %%
#remove the stop words
#remove the punctuations
for i in range(111):
    text=df['Text'][i]

    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    nofwords=len(word_list)
    outputfile.at[i,'WORD COUNT']=nofwords
outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0       1  https://insights.blackcoffer.com/how-is-login-...            81.0
# 1       2  https://insights.blackcoffer.com/how-does-ai-h...            61.0
# 2       3  https://insights.blackcoffer.com/ai-and-its-im...            85.0
# 3       4  https://insights.blackcoffer.com/how-do-deep-l...            73.0
# 4       5  https://insights.blackcoffer.com/how-artificia...            74.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            82.0       -0.006135            0.120920            20.175438
# 1            74.0       -0.096296            0.135815            11.056338
# 2            89.0       -0.022989            0.143564            15.208955
# 3            69.0        0.028169            0.127126            11.750000
# 4            81.0       -0.045161            0.126016            13.026316
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                     0.768696   8.377654                         20.175439
# 1                     0.668790   4.690051                         11.056338
# 2                     0.787046   6.398400                         15.208955
# 3                     0.667021   4.966808                         11.750000
# 4                     0.727273   5.501435                         13.026316
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0               607.0      1150.0                NaN                NaN
# 1               607.0       785.0                NaN                NaN
# 2               607.0      1019.0                NaN                NaN
# 3               607.0       940.0                NaN                NaN
# 4               607.0       990.0                NaN                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# **SYLLABLE COUNT PER WORD**

# %%
#scpw=total no. of syllables in the text/total no of words
for i in range(111):
    text=df['Text'][i]
    vowels='aeiou'
    nofs=0
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    
    nofwords=len(word_list)
    for l in text:
        if l in vowels:
            nofs+=1
    
    scpw=nofs/nofwords  
    
    
    
    outputfile.at[i,'SYLLABLE PER WORD']=nofs
    
outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0       1  https://insights.blackcoffer.com/how-is-login-...            81.0
# 1       2  https://insights.blackcoffer.com/how-does-ai-h...            61.0
# 2       3  https://insights.blackcoffer.com/ai-and-its-im...            85.0
# 3       4  https://insights.blackcoffer.com/how-do-deep-l...            73.0
# 4       5  https://insights.blackcoffer.com/how-artificia...            74.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            82.0       -0.006135            0.120920            20.175438
# 1            74.0       -0.096296            0.135815            11.056338
# 2            89.0       -0.022989            0.143564            15.208955
# 3            69.0        0.028169            0.127126            11.750000
# 4            81.0       -0.045161            0.126016            13.026316
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                     0.768696   8.377654                         20.175439
# 1                     0.668790   4.690051                         11.056338
# 2                     0.787046   6.398400                         15.208955
# 3                     0.667021   4.966808                         11.750000
# 4                     0.727273   5.501435                         13.026316
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0               607.0      1150.0             3123.0                NaN
# 1               607.0       785.0             1872.0                NaN
# 2               607.0      1019.0             2828.0                NaN
# 3               607.0       940.0             2160.0                NaN
# 4               607.0       990.0             2492.0                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# **PERSONAL PRONOUNS**

# %%
ppc=0
pp=['I','we','We','WE','my','My','MY','ours','OURS','Ours','us','Us']
for i in range(111):
    ppc=0
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    for w in word_list:
        if w in pp:
            ppc+=1
    outputfile.at[i,'PERSONAL PRONOUNS']=ppc
outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0       1  https://insights.blackcoffer.com/how-is-login-...            81.0
# 1       2  https://insights.blackcoffer.com/how-does-ai-h...            61.0
# 2       3  https://insights.blackcoffer.com/ai-and-its-im...            85.0
# 3       4  https://insights.blackcoffer.com/how-do-deep-l...            73.0
# 4       5  https://insights.blackcoffer.com/how-artificia...            74.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            82.0       -0.006135            0.120920            20.175438
# 1            74.0       -0.096296            0.135815            11.056338
# 2            89.0       -0.022989            0.143564            15.208955
# 3            69.0        0.028169            0.127126            11.750000
# 4            81.0       -0.045161            0.126016            13.026316
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                     0.768696   8.377654                         20.175439
# 1                     0.668790   4.690051                         11.056338
# 2                     0.787046   6.398400                         15.208955
# 3                     0.667021   4.966808                         11.750000
# 4                     0.727273   5.501435                         13.026316
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0               607.0      1150.0             3123.0                1.0
# 1               607.0       785.0             1872.0                1.0
# 2               607.0      1019.0             2828.0                1.0
# 3               607.0       940.0             2160.0                1.0
# 4               607.0       990.0             2492.0                1.0
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# **AVERAGE WORD LENGTH**

# %%
#avgwl=sum of the no of chars in each word/total no ofwords
for i in range(111):
    text=df['Text'][i]
    #to find no. of words
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    nofwords=len(word_list)
    
    #to find sum of chars
    nofc=0
    for w in word_list:
        cpw=len(w)
        nofc+=cpw
    avgwl=nofc/nofwords
        
    
    outputfile.at[i,'AVG WORD LENGTH']=avgwl
outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0       1  https://insights.blackcoffer.com/how-is-login-...            81.0
# 1       2  https://insights.blackcoffer.com/how-does-ai-h...            61.0
# 2       3  https://insights.blackcoffer.com/ai-and-its-im...            85.0
# 3       4  https://insights.blackcoffer.com/how-do-deep-l...            73.0
# 4       5  https://insights.blackcoffer.com/how-artificia...            74.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            82.0       -0.006135            0.120920            20.175438
# 1            74.0       -0.096296            0.135815            11.056338
# 2            89.0       -0.022989            0.143564            15.208955
# 3            69.0        0.028169            0.127126            11.750000
# 4            81.0       -0.045161            0.126016            13.026316
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                     0.768696   8.377654                         20.175439
# 1                     0.668790   4.690051                         11.056338
# 2                     0.787046   6.398400                         15.208955
# 3                     0.667021   4.966808                         11.750000
# 4                     0.727273   5.501435                         13.026316
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0               607.0      1150.0             3123.0                1.0
# 1               607.0       785.0             1872.0                1.0
# 2               607.0      1019.0             2828.0                1.0
# 3               607.0       940.0             2160.0                1.0
# 4               607.0       990.0             2492.0                1.0
#
#    AVG WORD LENGTH
# 0         7.267826
# 1         6.412739
# 2         7.245339
# 3         6.346809
# 4         6.798990

# %%
outputfile.to_csv('mdoutputfile.csv',index=False)
